# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from dateutil.parser import parse
from datetime import date

# %%
df=pd.read_csv('../data다운로드파일/인천광역시_반려동물 보유 및 등록 현황_20191231.csv', encoding='MS949')

# %%
df1=pd.read_csv('../data다운로드파일/반려동물등록현황.csv', encoding='MS949')

# %%
df
# Out:
#       구  개 보유 여부 (%)  고양이 보유 여부 (%)  기타 보유 여부 (%)  반려동물 없음 (%)  \
# 0    동구         83.6           16.5           1.0         86.1
# 1  미추홀구         90.1           12.2           4.0         87.5
# 2   연수구         78.3           17.3           6.9         87.7
# 3   남동구         83.8           18.9           6.2         84.6
# 4   부평구         76.1           17.5           9.3         84.8
# 5   계양구         78.5           22.5           3.1         85.6
# 6    서구         76.5           20.1           7.9         81.6
# 7   강화군         92.4           18.0           2.9         76.6
# 8   옹진군         79.0           36.4           3.4         74.2
#
#    개 보유 수(평균) (마리)  고양이 보유 수(평균) (마리)  기타 보유 수(평균) (마리)  반려견 등록 (%)  \
# 0              1.2                1.5               4.0        66.1
# 1              1.2                1.5               2.0        48.8
# 2              1.2                1.6               1.7        52.0
# ...

# %%
df1
# Out:
#      시군명 읍면동명  등록동물수(마리)  (등록주체)시군구등록  (등록주체)대행업체등록  (등록주체)기타  (RFID종류)내장형  \
# 0    가평군  가평읍        941          NaN           NaN       NaN          596
# 1    가평군   북면        289          NaN           NaN       NaN          176
# 2    가평군   상면        399          NaN           NaN       NaN          217
# 3    가평군  설악면       1111          NaN           NaN       NaN          446
# 4    가평군  조종면        416          NaN           NaN       NaN          218
# ..   ...  ...        ...          ...           ...       ...          ...
# 732  화성시  청계동       2046         90.0        1956.0       0.0         1052
# 733  화성시  팔탄면        753         87.0         665.0       1.0          345
# 734  화성시  향남읍       5180        314.0        4863.0       3.0         2110
# 735  화성시  활초동         15          0.0          15.0       0.0            4
# 736  화성시  황계동         52         16.0          36.0       0.0           19
#
# ...

# %%
df1['시군명'].value_counts()
# Out:
# 수원시     55
# 고양시     53
# 화성시     52
# 성남시     46
# 안성시     46
# 평택시     38
# 용인시     36
# 파주시     35
# 여주시     32
# 안산시     31
# 시흥시     30
# 이천시     25
# 부천시     25
# 오산시     24
# 하남시     23
# 양주시     22
# 광주시     22
# 포천시     18
# 남양주시    16
# 김포시     15
# 동두천시    12
# 양평군     12
# 의왕시     11
# 과천시     10
# 연천군     10
# 군포시      9
# 광명시      8
# 구리시      7
# 안양시      7
# 가평군      6
# 의정부시     1
# Name: 시군명, dtype: int64
